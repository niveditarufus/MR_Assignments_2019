# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

img1_points =np.array([[381,402,1],
 [452,497,1],
 [671,538,1],
 [501,254,1],
 [506,381,1],
 [474,440,1],
 [471,537,1],
 [498,364,1],
 [706,319,1],
 [635,367,1]])

# %%
img2_points = np.array([[390,346,1],
 [439,412,1],
 [651,417,1],
 [477,194,1],
 [482,300,1],
 [456,359,1],
 [454,444,1],
 [475,287,1],
 [686,185,1],
 [606,253,1]])

# %%
Fmatrix =  np.array([[-1.29750186e-06, 8.07894025e-07, 1.84071967e-03],
[3.54098411e-06,1.05620725e-06,-8.90168709e-03],
[-3.29878312e-03,5.14822628e-03,1.00000000e+00]])

# %%
img1 = cv2.imread('img1.jpg',0)
img2 = cv2.imread('img2.jpg',0)
print(img2.shape)
print(img2_points[0].shape)
# Out:
# (720, 1280)
# (3,)

# %%
lxd0 = np.matmul(Fmatrix,img1_points[0])
lxd1 = np.matmul(Fmatrix,img1_points[1])
lxd2 = np.matmul(Fmatrix,img1_points[2])
lxd3 = np.matmul(Fmatrix,img1_points[3])
lxd4 = np.matmul(Fmatrix,img1_points[4])
lxd5 = np.matmul(Fmatrix,img1_points[5])
lxd6 = np.matmul(Fmatrix,img1_points[6])
lxd7 = np.matmul(Fmatrix,img1_points[7])
lxd8 = np.matmul(Fmatrix,img1_points[8])
lxd9 = np.matmul(Fmatrix,img1_points[9])


lx0 = np.matmul(img2_points[0].T,Fmatrix)
lx1 = np.matmul(img2_points[1].T,Fmatrix)
lx2 = np.matmul(img2_points[2].T,Fmatrix)
lx3 = np.matmul(img2_points[3].T,Fmatrix)
lx4 = np.matmul(img2_points[4].T,Fmatrix)
lx5 = np.matmul(img2_points[5].T,Fmatrix)
lx6 = np.matmul(img2_points[6].T,Fmatrix)
lx7 = np.matmul(img2_points[7].T,Fmatrix)
lx8 = np.matmul(img2_points[8].T,Fmatrix)
lx9 = np.matmul(img2_points[9].T,Fmatrix)

# %%
x0 = np.linspace(0,1280,num = 1280)
y0 = -lxd0[2]/lxd0[1] - x0*lxd0[0]/lxd0[1]

x1 = np.linspace(0,1280,num = 1280)
y1 = -lxd1[2]/lxd1[1] - x1*lxd1[0]/lxd1[1]

x2 = np.linspace(0,1280,num = 1280)
y2 = -lxd2[2]/lxd2[1] - x2*lxd2[0]/lxd2[1]

x3 = np.linspace(0,1280,num = 1280)
y3 = -lxd3[2]/lxd3[1] - x3*lxd3[0]/lxd3[1]

x4 = np.linspace(0,1280,num = 1280)
y4 = -lxd4[2]/lxd4[1] - x4*lxd4[0]/lxd4[1]

x5 = np.linspace(0,1280,num = 1280)
y5 = -lxd5[2]/lxd5[1] - x5*lxd5[0]/lxd5[1]

x6 = np.linspace(0,1280,num = 1280)
y6 = -lxd6[2]/lxd6[1] - x6*lxd6[0]/lxd6[1]

x7 = np.linspace(0,1280,num = 1280)
y7 = -lxd7[2]/lxd7[1] - x7*lxd7[0]/lxd7[1]

x8 = np.linspace(0,1280,num = 1280)
y8 = -lxd8[2]/lxd8[1] - x8*lxd8[0]/lxd8[1]

x9 = np.linspace(0,1280,num = 1280)
y9 = -lxd9[2]/lxd9[1] - x9*lxd9[0]/lxd9[1]

plt.imshow(img2,cmap = 'gray')
plt.plot(x0,y0)
plt.scatter(img2_points[0][0],img2_points[0][1],s=100)
plt.plot(x1,y1)
plt.scatter(img2_points[1][0],img2_points[1][1],s=100)
plt.plot(x2,y2)
plt.scatter(img2_points[2][0],img2_points[2][1],s=100)
plt.plot(x3,y3)
plt.scatter(img2_points[3][0],img2_points[3][1],s=100)
plt.plot(x4,y4)
plt.scatter(img2_points[4][0],img2_points[4][1],s=100)
plt.plot(x5,y5)
plt.scatter(img2_points[5][0],img2_points[5][1],s=100)
plt.plot(x6,y6)
plt.scatter(img2_points[6][0],img2_points[6][1],s=100)
plt.plot(x7,y7)
plt.scatter(img2_points[7][0],img2_points[7][1],s=100)
plt.plot(x8,y8)
plt.scatter(img2_points[8][0],img2_points[8][1],s=100)
plt.plot(x9,y9)
plt.scatter(img2_points[9][0],img2_points[9][1],s=100)

# %%
xd0 = np.linspace(0,1280,num = 1280)
yd0 = -lx0[2]/lx0[1] - x0*lx0[0]/lx0[1]

xd1 = np.linspace(0,1280,num = 1280)
yd1 = -lx1[2]/lx1[1] - x1*lx1[0]/lx1[1]

xd2 = np.linspace(0,1280,num = 1280)
yd2 = -lx2[2]/lx2[1] - x2*lx2[0]/lx2[1]

xd3 = np.linspace(0,1280,num = 1280)
yd3 = -lx3[2]/lx3[1] - x3*lx3[0]/lx3[1]

xd4 = np.linspace(0,1280,num = 1280)
yd4 = -lx4[2]/lx4[1] - x4*lx4[0]/lx4[1]

xd5 = np.linspace(0,1280,num = 1280)
yd5 = -lx5[2]/lx5[1] - x5*lx5[0]/lx5[1]

xd6 = np.linspace(0,1280,num = 1280)
yd6 = -lx6[2]/lx6[1] - x6*lx6[0]/lx6[1]

xd7 = np.linspace(0,1280,num = 1280)
yd7 = -lx7[2]/lx7[1] - x7*lx7[0]/lx7[1]

xd8 = np.linspace(0,1280,num = 1280)
yd8 = -lx8[2]/lx8[1] - x8*lx8[0]/lx8[1]

xd9 = np.linspace(0,1280,num = 1280)
yd9 = -lx9[2]/lx9[1] - x9*lx9[0]/lx9[1]

plt.imshow(img1,cmap = 'gray')
plt.plot(xd0,yd0)
plt.scatter(img1_points[0][0],img1_points[0][1],s=100)
plt.plot(xd1,yd1)
plt.scatter(img1_points[1][0],img1_points[1][1],s=100)
plt.plot(xd2,yd2)
plt.scatter(img1_points[2][0],img1_points[2][1],s=100)
plt.plot(xd3,yd3)
plt.scatter(img1_points[3][0],img1_points[3][1],s=100)
plt.plot(xd4,yd4)
plt.scatter(img1_points[4][0],img1_points[4][1],s=100)
plt.plot(xd5,yd5)
plt.scatter(img1_points[5][0],img1_points[5][1],s=100)
plt.plot(xd6,yd6)
plt.scatter(img1_points[6][0],img1_points[6][1],s=100)
plt.plot(xd7,yd7)
plt.scatter(img1_points[7][0],img1_points[7][1],s=100)
plt.plot(xd8,yd8)
plt.scatter(img1_points[8][0],img1_points[8][1],s=100)
plt.plot(xd9,yd9)
plt.scatter(img1_points[9][0],img1_points[9][1],s=100)

# %%
#epipole calculation
u, s, vh = np.linalg.svd(np.matmul(Fmatrix,Fmatrix.T))
print(u)
eigenval = u[:,2]
print(eigenval)
pt = eigenval / eigenval[2]
print(pt)
# Out:
# [[-1.84058326e-03  1.81802331e-01 -9.83333374e-01]
#  [ 8.90099287e-03 -9.83293107e-01 -1.81811547e-01]
#  [-9.99958691e-01 -9.08728264e-03  1.91611586e-04]]
# [-9.83333374e-01 -1.81811547e-01  1.91611586e-04]
# [-5.13190979e+03 -9.48854662e+02  1.00000000e+00]

# %%
u, s, vh = np.linalg.svd(np.matmul(Fmatrix.T,Fmatrix))
print(u)
eigenval = u[:,2]
print(eigenval)
pt = eigenval / eigenval[2]
print(pt)
# Out:
# [[-3.29848284e-03  4.82445292e-01  8.75919894e-01]
#  [ 5.14769682e-03 -8.75904861e-01  4.82456398e-01]
#  [ 9.99981310e-01  6.10034420e-03  4.05675055e-04]]
# [8.75919894e-01 4.82456398e-01 4.05675055e-04]
# [2.15916627e+03 1.18926809e+03 1.00000000e+00]
